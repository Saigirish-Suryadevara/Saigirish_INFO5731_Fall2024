# %% [markdown]
# <a href="https://colab.research.google.com/github/Saigirish-Suryadevara/Saigirish_INFO5731_Fall2024/blob/main/Saigirish_Suryadevara_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 In-class Exercise 2**
#
# The purpose of this exercise is to understand users' information needs, and then collect data from different sources for analysis by implementing web scraping using Python.
#
# **Expectations**:
# *   Students are expected to complete the exercise during lecture period to meet the active participation criteria of the course.
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# **Total points**: 40
#
# **Deadline**: This in-class exercise is due at the end of the day tomorrow, at 11:59 PM.
#
# **Late submissions will have a penalty of 10% of the marks for each day of late submission. , and no requests will be answered. Manage your time accordingly.**

# %% [markdown]
# ## Question 1 (10 Points)
# Describe an interesting research question (or practical question or something innovative) you have in mind, what kind of data should be collected to answer the question(s)? Specify the amount of data needed for analysis. Provide detailed steps for collecting and saving the data.

# %%
# write your answer here
"""How did the Consumer thought process and discussion about Videogame Consoles change over time and how did this effect or changed the Videogame market?
Collecting data from youtube comments on videos based on videogame console sales, to analyse evolution in consumer nature of buying videogame consoles and anlysing console market.
Moreover we need to collect comment text, no of likes, comment date and video id from which each comment is fetched.
Ensuring to collect atleat 1000 of comments to get a comprehensive dataset to analyse various patterns and trends.
I have used youtube api to search for videos realted to videogame consoles, the i have retrieved the video ID from the search results.
For video i have used youtube API to collect the comments, including id,likes and posted date, used pagination to collect all the comments from the video.
Later all the comments are collected and complied to a dataframe and exported the data to a CSV file.
"""

# %% [markdown]
# ## Question 2 (10 Points)
# Write Python code to collect a dataset of 1000 samples related to the question discussed in Question 1.

# %%
import googleapiclient.discovery
import pandas as pd
from googleapiclient.discovery import build

def fetch_and_save_youtube_comments():
    api_key = 'AIzaSyCAPelAuaDMZ3EEg5BtmO-UD5uNF2G86jM'  # Your API key

    # Build the YouTube API service
    youtube = build('youtube', 'v3', developerKey=api_key)

    # Create lists to store comment data
    comment_thread_ids = []
    author_display_names = []
    comment_texts = []
    like_counts = []

    # Create a request to retrieve comment threads for a specific video
    request = youtube.commentThreads().list(
        part='id,snippet,replies',  # Parts to include in the response
        videoId='oWmdxeAFS-I',      # ID of the video
        maxResults=1000              # Limit the number of results per request
    )

    # Execute the request and get the response
    response = request.execute()

    # Function to parse comment data and append it to lists
    def parse_comment_data(comment):
        comment_thread_ids.append(comment['id'])
        snippet = comment['snippet']['topLevelComment']['snippet']
        author_display_names.append(snippet['authorDisplayName'])
        comment_texts.append(snippet['textDisplay'])
        like_counts.append(snippet['likeCount'])

    # Parse the initial response
    for item in response['items']:
        parse_comment_data(item)

    # Loop through additional pages if available
    while 'nextPageToken' in response:
        request = youtube.commentThreads().list(
            part='id,snippet,replies',
            videoId='cV5TjZCJkuA',
            pageToken=response['nextPageToken'],
            maxResults=100
        )
        response = request.execute()
        for item in response['items']:
            parse_comment_data(item)

    # Create a DataFrame from the parsed data
    comments_df = pd.DataFrame({
        'Comment Thread ID': comment_thread_ids,
        'Author Display Name': author_display_names,
        'Comment Text': comment_texts,
        'Like Count': like_counts
    })

    # Saving dataframe to a csv file

    comments_df.to_csv('youtube_comments.csv', index=False)

    print("CSV file has been created successfully!")

fetch_and_save_youtube_comments()
# Out:
# CSV file has been created successfully!

# %%
df = pd.read_csv('youtube_comments.csv')
df.head(1000)
# Out:
#               Comment Thread ID  Author Display Name  \
# 0    UgwG7c5T-LTsVAsYdDN4AaABAg        @CaptainGizmo
# 1    UgwRb6iE_cdEarIcdeJ4AaABAg      @darthwoody9917
# 2    UgzTgXDKF3bKNqODGY54AaABAg         @JosheiAkuma
# 3    UgxB2gcsg5qbTvm3zR14AaABAg        @AnneMcFadden
# 4    UgycmtGCDLJTDHUPjGp4AaABAg      @svenbalzer6763
# ..                          ...                  ...
# 995  Ugy5HINxLpdoqnKLDoF4AaABAg  @muhammadfarhad2640
# 996  UgwMolFSVjix36RRMKB4AaABAg       @Tranquility._
# 997  UgyF_5JKw2a1fZ4k3EF4AaABAg    @mustafamalik4211
# 998  UgwDbU_x4I28G8kzx-F4AaABAg           @suzyq4433
# 999  UgxyOk4RwgprTCL_WF14AaABAg   @robbiewishart2549
#
#                                           Comment Text  Like Count
# 0    Amazon has a special section for retro gaming:...      4117.0
# 1    If Nintendo actually decided to work with Sony...         0.0
# 2                                 It’s  obviously Sony         0.0
# ...

# %% [markdown]
# ## Question 3 (10 Points)
# Write Python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "XYZ". The articles should be published in the last 10 years (2014-2024).
#
# The following information from the article needs to be collected:
#
# (1) Title of the article
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
! pip install --upgrade semanticscholar

# %%
from logging import exception
import semanticscholar
from datetime import datetime

# defining functionto fetch articles
def scrape_semantic_articles(keyword, startyear, endyear):
  publications=[]
  scholar = semanticscholar.SemanticScholar()

  try:
    for article in scholar.search_paper(query=keyword, year=f"{startyear}-{endyear}"):
      article_title = article.title
      venue = article.venue
      year = article.year
      authors_name = [author.name for author in article.authors]
      abstract = article.abstract

      publications.append({
          "Article Title": article_title,
          "Venue": venue,
          "Published_Year": year,
          "Authors": authors_name,
          "Abstract": abstract

      })

      if len(publications) >=1000:
        break
  except Exception as e:
    print(f"Cannot process heavy request:{e}")

  return publications

# defining parameters
keyword= "XYZ"
startyear = 2014
endyear = 2024

publications = scrape_semantic_articles(keyword,startyear,endyear)
print("Fetched Articles:")
for p in publications:
  print(p)
# Out:
# Cannot process heavy request:RetryError[<Future at 0x7cb858444940 state=finished raised ConnectionRefusedError>]
# Fetched Articles:
# ...

# %% [markdown]
# ## Question 4A (10 Points)
# Develop Python code to collect data from social media platforms like Reddit, Instagram, Twitter (formerly known as X), Facebook, or any other. Use hashtags, keywords, usernames, or user IDs to gather the data.
#
#
#
# Ensure that the collected data has more than four columns.

# %%
import googleapiclient.discovery
import pandas as pd
from googleapiclient.discovery import build

def fetch_and_save_youtube_comments():
    api_key = 'AIzaSyCAPelAuaDMZ3EEg5BtmO-UD5uNF2G86jM'  # Your API key

    # Build the YouTube API service
    youtube = build('youtube', 'v3', developerKey=api_key)

    # Create lists to store comment data
    comment_thread_ids = []
    author_display_names = []
    comment_texts = []
    like_counts = []

    # Create a request to retrieve comment threads for a specific video
    request = youtube.commentThreads().list(
        part='id,snippet,replies',  # Parts to include in the response
        videoId='cV5TjZCJkuA',      # ID of the video
        maxResults=100              # Limit the number of results per request
    )

    # Execute the request and get the response
    response = request.execute()

    # Function to parse comment data and append it to lists
    def parse_comment_data(comment):
        comment_thread_ids.append(comment['id'])
        snippet = comment['snippet']['topLevelComment']['snippet']
        author_display_names.append(snippet['authorDisplayName'])
        comment_texts.append(snippet['textDisplay'])
        like_counts.append(snippet['likeCount'])

    # Parse the initial response
    for item in response['items']:
        parse_comment_data(item)

    # Loop through additional pages if available
    while 'nextPageToken' in response:
        request = youtube.commentThreads().list(
            part='id,snippet,replies',
            videoId='cV5TjZCJkuA',
            pageToken=response['nextPageToken'],
            maxResults=100
        )
        response = request.execute()
        for item in response['items']:
            parse_comment_data(item)

    # Create a DataFrame from the parsed data
    comments_df = pd.DataFrame({
        'Comment Thread ID': comment_thread_ids,
        'Author Display Name': author_display_names,
        'Comment Text': comment_texts,
        'Like Count': like_counts
    })

    # Print the DataFrame
    print(comments_df)

# Call the function to fetch and print YouTube comments
fetch_and_save_youtube_comments()
# Out:
#                 Comment Thread ID    Author Display Name  \
# 0      Ugzt7jLwQ2Hv_YWLoIp4AaABAg          @unboxtherapy
# 1      Ugy2XEl_iuSHZautvTZ4AaABAg            @DominikoPL
# 2      UgylvR63PowUjJtu4jt4AaABAg  @LegendairyRandomness
# 3      UgwjN_xeSvC3BkzvBOt4AaABAg    @CEDRIC_HERNANDEZ77
# 4      Ugw75Rl0qfjd16RFu814AaABAg        @stephantds4071
# ...                           ...                    ...
# 20467  Ugwkt1em_F9GFf3Jecd4AaABAg         @HansanaPeiris
# 20468  Ugx0QeJjyr7nL7yBlmp4AaABAg               @Rival13
# 20469  UgwTzvP5o1TiQUmarAp4AaABAg      @hehtjosiajdjd468
# 20470  UgyGMHQU1rGmCZ9glgh4AaABAg        @yvardeboer9431
# 20471  UgxeecUXKIwv2wicTlt4AaABAg                @nnctxv
#
#                                             Comment Text  Like Count
# 0                          What is your next smartphone?       10638
# 1      I think it&#39;s hilarious that this fad of ca...           1
# 2      Crazy that this is 6 years ago, now I&#39;m wa...           2
# ...

# %% [markdown]
# ## Question 4B (10 Points)
# If you encounter challenges with Question-4 web scraping using Python, employ any online tools such as ParseHub or Octoparse for data extraction. Introduce the selected tool, outline the steps for web scraping, and showcase the final output in formats like CSV or Excel.
#
#
#
# Upload a document (Word or PDF File) in any shared storage (preferably UNT OneDrive) and add the publicly accessible link in the below code cell.
#
# Please only choose one option for question 4. If you do both options, we will grade only the first one

# %%
# write your answer here

# %% [markdown]
# # Mandatory Question

# %% [markdown]
# **Important: Reflective Feedback on Web Scraping and Data Collection**
#
#
#
# Please share your thoughts and feedback on the web scraping and data collection exercises you have completed in this assignment. Consider the following points in your response:
#
#
#
# Learning Experience: Describe your overall learning experience in working on web scraping tasks. What were the key concepts or techniques you found most beneficial in understanding the process of extracting data from various online sources?
#
#
#
# Challenges Encountered: Were there specific difficulties in collecting data from certain websites, and how did you overcome them? If you opted for the non-coding option, share your experience with the chosen tool.
#
#
#
# Relevance to Your Field of Study: How might the ability to gather and analyze data from online sources enhance your work or research?
#
# **(no grading of your submission if this question is left unanswered)**

# %%
'''
Write your response here.

Webscraping has been a good learning experience and enhanced the importance of data extraction and understanding HTMl structure. Keytechniques like beautiful soup,scrappy and data scraping using API have been very effective
in webscraping. I have faced issues like varying HTML structrues, rate limit issues and anti-scraping meaures which complicated data extraction. During my previous project which i worked, i have used google api to extract data
from youtube comments to create an ETL Pipeline, the similar code i have used in question 4A and 2 in this class excercise. With excercise apart form API, i have also used and came across beautiful soup to scrape the webpages.

'''
